# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  # y=mx+c
#
#  # some assumption
#
# - there should be a relationship between x and y
# - mean of resudal  should be zero
# - Error term are not supposed to be corellated
# - X and residual  must be uncorelated
# - Error term must showcase constant varience
# - No multi colinearity
# - Error term are supposed to be normally distributed
# ## What is residual?
# - r=y-y^
# - r = y-(mx+c)
# - RSS=\sum \limits_{i=1}^{n} (y_i-f(x_i))^2
